# %%
import tensorflow as tf
import os,sys
import warnings
warnings.filterwarnings('ignore')
import logging
logging.getLogger('tensorflow').disabled = True
# gpu_devices = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(gpu_devices[0], True)

print(tf.test.is_gpu_available())
print(tf.test.is_built_with_cuda())

os.chdir("/home/rangulov/EmotionRecognition")
ROOT_DIR = os.path.abspath(".")
sys.path.append(ROOT_DIR)
import src.config
print(src.config.PROCESSED_FRAMES_DATA_DIR)
# Out:
# True
# True
# /home/rangulov/cropped_aligned

# %%
# %run src/train_cnn.py
# Out:
# Loading Simple CNN by Khorrami with CCC loss
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 96, 96, 1)         4
# _________________________________________________________________
# conv2d (Conv2D)              (None, 96, 96, 64)        1600
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 128)       204800
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 256)       819200
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 300)               307500
# _________________________________________________________________
# dropout (Dropout)            (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 602
# =================================================================
# Total params: 1,333,706
# Trainable params: 1,333,704
# Non-trainable params: 2
# _________________________________________________________________
# None
# Epoch 1/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6006 - rmse: 0.4239 - rmse_v: 0.4869 - rmse_a: 0.3609 - cc_v: 0.3898 - cc_a: 0.4304 - ccc_v: 0.3804 - ccc_a: 0.4184
# Epoch 00001: val_loss improved from inf to 0.77915, saving model to /home/rangulov/EmotionRecognition/data/checkpoints/simple_cnn_ccc_loss.0001-0.7792.hdf5
# 1000/1000 [==============================] - 330s 330ms/step - loss: 0.6006 - rmse: 0.4239 - rmse_v: 0.4869 - rmse_a: 0.3609 - cc_v: 0.3898 - cc_a: 0.4304 - ccc_v: 0.3804 - ccc_a: 0.4184 - val_loss: 0.7792 - val_rmse: 0.3638 - val_rmse_v: 0.4298 - val_rmse_a: 0.2977 - val_cc_v: 0.2389 - val_cc_a: 0.2412 - val_ccc_v: 0.2184 - val_ccc_a: 0.2233
# Epoch 2/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3209 - rmse: 0.3106 - rmse_v: 0.3609 - rmse_a: 0.2603 - cc_v: 0.6856 - cc_a: 0.6912 - ccc_v: 0.6765 - ccc_a: 0.6817
# Epoch 00002: val_loss did not improve from 0.77915
# 1000/1000 [==============================] - 329s 329ms/step - loss: 0.3209 - rmse: 0.3106 - rmse_v: 0.3609 - rmse_a: 0.2603 - cc_v: 0.6856 - cc_a: 0.6912 - ccc_v: 0.6765 - ccc_a: 0.6817 - val_loss: 0.7963 - val_rmse: 0.3757 - val_rmse_v: 0.4445 - val_rmse_a: 0.3068 - val_cc_v: 0.2188 - val_cc_a: 0.2314 - val_ccc_v: 0.1862 - val_ccc_a: 0.2212
# Epoch 3/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2540 - rmse: 0.2771 - rmse_v: 0.3198 - rmse_a: 0.2344 - cc_v: 0.7551 - cc_a: 0.7514 - ccc_v: 0.7482 - ccc_a: 0.7437
# Epoch 00003: val_loss did not improve from 0.77915
# 1000/1000 [==============================] - 328s 328ms/step - loss: 0.2540 - rmse: 0.2771 - rmse_v: 0.3198 - rmse_a: 0.2344 - cc_v: 0.7551 - cc_a: 0.7514 - ccc_v: 0.7482 - ccc_a: 0.7437 - val_loss: 0.8201 - val_rmse: 0.3725 - val_rmse_v: 0.4688 - val_rmse_a: 0.2762 - val_cc_v: 0.1694 - val_cc_a: 0.2611 - val_ccc_v: 0.1282 - val_ccc_a: 0.2316
# Epoch 4/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2196 - rmse: 0.2565 - rmse_v: 0.2939 - rmse_a: 0.2190 - cc_v: 0.7929 - cc_a: 0.7808 - ccc_v: 0.7872 - ccc_a: 0.7737
# Epoch 00004: val_loss did not improve from 0.77915
# 1000/1000 [==============================] - 326s 326ms/step - loss: 0.2196 - rmse: 0.2565 - rmse_v: 0.2939 - rmse_a: 0.2190 - cc_v: 0.7929 - cc_a: 0.7808 - ccc_v: 0.7872 - ccc_a: 0.7737 - val_loss: 0.8049 - val_rmse: 0.3608 - val_rmse_v: 0.4376 - val_rmse_a: 0.2839 - val_cc_v: 0.2010 - val_cc_a: 0.2488 - val_ccc_v: 0.1664 - val_ccc_a: 0.2238
# Epoch 5/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1986 - rmse: 0.2442 - rmse_v: 0.2805 - rmse_a: 0.2078 - cc_v: 0.8129 - cc_a: 0.8021 - ccc_v: 0.8071 - ccc_a: 0.7956
# Epoch 00005: val_loss did not improve from 0.77915
# 1000/1000 [==============================] - 325s 325ms/step - loss: 0.1986 - rmse: 0.2442 - rmse_v: 0.2805 - rmse_a: 0.2078 - cc_v: 0.8129 - cc_a: 0.8021 - ccc_v: 0.8071 - ccc_a: 0.7956 - val_loss: 0.8364 - val_rmse: 0.3626 - val_rmse_v: 0.4386 - val_rmse_a: 0.2866 - val_cc_v: 0.1542 - val_cc_a: 0.2316 - val_ccc_v: 0.1255 - val_ccc_a: 0.2017
# Epoch 6/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1826 - rmse: 0.2344 - rmse_v: 0.2688 - rmse_a: 0.2000 - cc_v: 0.8277 - cc_a: 0.8171 - ccc_v: 0.8231 - ccc_a: 0.8117
# Epoch 00006: val_loss did not improve from 0.77915
# 1000/1000 [==============================] - 325s 325ms/step - loss: 0.1826 - rmse: 0.2344 - rmse_v: 0.2688 - rmse_a: 0.2000 - cc_v: 0.8277 - cc_a: 0.8171 - ccc_v: 0.8231 - ccc_a: 0.8117 - val_loss: 0.8490 - val_rmse: 0.3728 - val_rmse_v: 0.4613 - val_rmse_a: 0.2843 - val_cc_v: 0.1416 - val_cc_a: 0.2232 - val_ccc_v: 0.1090 - val_ccc_a: 0.1930
# Epoch 7/100
#   79/1000 [=>............................] - ETA: 2:36 - loss: 0.1715 - rmse: 0.2267 - rmse_v: 0.2582 - rmse_a: 0.1953 - cc_v: 0.8415 - cc_a: 0.8247 - ccc_v: 0.8372 - ccc_a: 0.8198
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/EmotionRecognition/src/train_cnn.py in <module>
#      67
#      68 if __name__ == '__main__':
# ---> 69     main()
#
# ~/EmotionRecognition/src/train_cnn.py in main()
#      63
#      64     generators = get_generators('simple-cnn')
# ---> 65     train_model(research_model, 100, generators, [checkpointer, tensorboard_callback])
#      66
#      67
#
# ~/EmotionRecognition/src/train_cnn.py in train_model(research_model, nb_epoch, generators, callbacks)
#      42         validation_data=validation_generator,
#      43         epochs=nb_epoch,
# ---> 44         callbacks=callbacks)
#      45
#      46
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1477         use_multiprocessing=use_multiprocessing,
#    1478         shuffle=shuffle,
# -> 1479         initial_epoch=initial_epoch)
#    1480
#    1481   @deprecation.deprecated(
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
